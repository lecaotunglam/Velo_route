# %% [markdown]
# <h1>Experience vélo à Saint Denis</h1>

# %% [markdown]
# Section 1

# %%
import pandas as pd
from pandas import isnull

from sympy.integrals.meijerint_doc import category

photo= pd.read_csv('Photo.csv')

# %%
import folium
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from IPython.display import display

# Assuming 'photo' is your pandas DataFrame with columns: 'Latitude', 'Longitude', and 'Filename'
# Example:
# photo = pd.DataFrame({
#     'Latitude': [48.909431, 48.85837],
#     'Longitude': [2.366886, 2.294481],
#     'Filename': ['image1.jpg', 'image2.jpg']
# })

# Directory where images are stored
image_directory = "Photo Saint-Denis/"

# Convert the pandas DataFrame to a GeoDataFrame
geometry = [Point(lon, lat) for lon, lat in zip(photo['Longitude'], photo['Latitude'])]
gdf = gpd.GeoDataFrame(photo, geometry=geometry, crs="EPSG:4326")

# Create a base map centered on the mean of the coordinates
m = folium.Map(location=[gdf['Latitude'].mean(), gdf['Longitude'].mean()], zoom_start=14, tiles='Stadia.OSMBright')

# Add points to the map
for idx, row in gdf.iterrows():
    # Construct the full path to the image
    image_path = f"{image_directory}{row['Filename']}"

    # HTML for the popup with the image
    popup_content = f"<img src='{image_path}' width='200'>"

    # Add a marker with the popup
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(popup_content, max_width=250)
    ).add_to(m)

# Save the map to an HTML file
m.save('map.html')

# Display the map (if in a Jupyter Notebook)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de6afeadc5f0eb2600f0a72f286916ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de6afeadc5f0eb2600f0a72f286916ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de6afeadc5f0eb2600f0a72f286916ec = L.map(
#                 &quot;map_de6afeadc5f0eb2600f0a72f286916ec&quot;,
#                 {
#                     center: [48.909533499999995, 2.36840525],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15db1f0a320f735773debdb16d743efe = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://stadiamaps.com/\&quot;\u003eStadia Maps\u003c/a\u003e, \u0026copy; \u003ca href=\&quot;https://openmaptiles.org/\&quot;\u003eOpenMapTiles\u003c/a\u003e \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15db1f0a320f735773debdb16d743efe.addTo(map_de6afeadc5f0eb2600f0a72f286916ec);
#
#
#             var marker_946776cbcf98cd1d2b0abb3e65f76404 = L.marker(
#                 [48.909431, 2.366886],
#                 {
# }
#             ).addTo(map_de6afeadc5f0eb2600f0a72f286916ec);
#
#
#         var popup_a1a8dc04f95e9487766c893ee9077196 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_c1a46db139c42c46a56abcbd5bfa8fc1 = $(`&lt;div id=&quot;html_c1a46db139c42c46a56abcbd5bfa8fc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&#x27;Photo Saint-Denis/IMG_4635.JPG&#x27; width=&#x27;200&#x27;&gt;&lt;/div&gt;`)[0];
#                 popup_a1a8dc04f95e9487766c893ee9077196.setContent(html_c1a46db139c42c46a56abcbd5bfa8fc1);
#
#
#
#         marker_946776cbcf98cd1d2b0abb3e65f76404.bindPopup(popup_a1a8dc04f95e9487766c893ee9077196)
#         ;
#
#
#
#
#             var marker_e712cae5cb1ed592075201c9cdae9b67 = L.marker(
#                 [48.90905, 2.365422],
#                 {
# }
#             ).addTo(map_de6afeadc5f0eb2600f0a72f286916ec);
#
#
#         var popup_ceab2929019bedba28d786c9a8babc58 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_c9fa1cf7eb83990303a6abb2b81fa0b3 = $(`&lt;div id=&quot;html_c9fa1cf7eb83990303a6abb2b81fa0b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&#x27;Photo Saint-Denis/IMG_4636.JPG&#x27; width=&#x27;200&#x27;&gt;&lt;/div&gt;`)[0];
#                 popup_ceab2929019bedba28d786c9a8babc58.setContent(html_c9fa1cf7eb83990303a6abb2b81fa0b3);
#
#
#
#         marker_e712cae5cb1ed592075201c9cdae9b67.bindPopup(popup_ceab2929019bedba28d786c9a8babc58)
#         ;
#
#
#
#
#             var marker_f3839761d18764d6d26de1adf2664579 = L.marker(
#                 [48.906994, 2.364672],
#                 {
# }
#             ).addTo(map_de6afeadc5f0eb2600f0a72f286916ec);
#
#
#         var popup_b1bc2f29aca48a8fa46bd3bb4c3a5e92 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_e1f6a00c19dc88363b0d92332efff42d = $(`&lt;div id=&quot;html_e1f6a00c19dc88363b0d92332efff42d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&#x27;Photo Saint-Denis/IMG_4640.JPG&#x27; width=&#x27;200&#x27;&gt;&lt;/div&gt;`)[0];
#                 popup_b1bc2f29aca48a8fa46bd3bb4c3a5e92.setContent(html_e1f6a00c19dc88363b0d92332efff42d);
#
#
#
#         marker_f3839761d18764d6d26de1adf2664579.bindPopup(popup_b1bc2f29aca48a8fa46bd3bb4c3a5e92)
#         ;
#
#
#
#
#             var marker_7201b64b2d1c5498ceb78dce4a113ed3 = L.marker(
#                 [48.906958, 2.364658],
#                 {
# }
#             ).addTo(map_de6afeadc5f0eb2600f0a72f286916ec);
#
#
#         var popup_1e123cfacc29ba0d9c8c9adcdd2a614e = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_5020f7d6a4a95dafbe290bd2c5ce8fb8 = $(`&lt;div id=&quot;html_5020f7d6a4a95dafbe290bd2c5ce8fb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&#x27;Photo Saint-Denis/IMG_4641.JPG&#x27; width=&#x27;200&#x27;&gt;&lt;/div&gt;`)[0];
#                 popup_1e123cfacc29ba0d9c8c9adcdd2a614e.setContent(html_5020f7d6a4a95dafbe290bd2c5ce8fb8);
#
#
#
#         marker_7201b64b2d1c5498ceb78dce4a113ed3.bindPopup(popup_1e123cfacc29ba0d9c8c9adcdd2a614e)
#         ;
#
#
#
#
#             var marker_aa0bda626502a870b8ddb5c74020c5dc = L.marker(
#                 [48.906917, 2.365953],
#                 {
# }
#             ).addTo(map_de6afeadc5f0eb2600f0a72f286916ec);
#
#
#         var popup_490eba0327b2af0ca76487317b1c2338 = L.popup({
#   &quot

# %%
import plotly.graph_objects as go

fig = go.Figure([go.Scatter(x=photo['Time Taken'], y=photo['Altitude'])])
fig.show()
# Out:
# <div>                            <div id="df97d778-a583-4f09-8ace-b0d6c40da0cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df97d778-a583-4f09-8ace-b0d6c40da0cd")) {                    Plotly.newPlot(                        "df97d778-a583-4f09-8ace-b0d6c40da0cd",                        [{"x":["10:21:46","10:24:31","10:29:11","10:29:31","10:31:07","10:31:25","10:31:31","10:31:33","10:32:23","10:33:08","11:04:01","11:04:05","11:16:54","11:31:29","11:31:52","11:51:14"],"y":[51.78,58.58,54.7,56.5,50.2,48.9,49.39,49.43,40.86,48.92,51.78,52.61,43.89,55.5,56.96,55.16],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"marker":{"line":{"color":"#283442"}},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pa ...

# %% [markdown]
# Section 2 / Vélo route en Ile De France

# %%
# pip install geopandas
import geopandas

route_velo = geopandas.read_file('reseau-vif-velo-ile-de-france.geojson')
# Out:
# Skipping field j_num_ligne: unsupported OGR type: 5

# %%
route_velo
# Out:
#                                  gidtroncon  \
# 0    {3571ECAC-17F3-454D-B70B-56B0EDF5D4B2}
# 1    {BCF20960-888B-4D73-B6F1-6EE6AE45F01D}
# 2    {8492CCED-90A1-4A7D-9B7E-CBC58C4AFE59}
# 3    {0688B052-EA7B-414E-A876-E6848F7B6DBC}
# 4    {453270D4-70B9-4E8A-A1E3-D0C804391B30}
# ..                                      ...
# 820  {5DFE548D-BC26-44B9-98E0-B65B4F272ECD}
# 821  {E755DEE3-80E1-41AB-B8E9-0CBE8D8A2EA9}
# 822  {006AA600-1AFD-4B36-893A-0B628B685B75}
# 823  {B3A9FAF0-1D2B-4898-A387-DCF534087A76}
# 824  {8BC9D2F3-5864-45BD-8D56-90C051F15A77}
#
#                                          numero_ligne niveau_valid_amenag  \
# 0      <ul class="lignes"><li class="v6">V6</li></ul>   Pas d'information
# 1      <ul class="lignes"><li class="v6">V6</li></ul>      Mis en service
# 2      <ul class="lignes"><li class="v7">V7</li></ul>      Mis en service
# 3      <ul class="lignes"><li class="v7">V7</li></ul>           À l'étude
# 4    <ul class="lignes"><li class="v20">V20</li></ul>      Mis en service
# ..                                                ...                 ...
# 820    <ul class="lignes"><li class="v8">V8</li></ul>   Pas d'information
# 821    <ul class="lignes"><li class="v1">V1</li></ul>      Mis en service
# 822    <ul class="lignes"><li class="v1">V1</li></ul>      Mis en service
# 823    <ul class="lignes"><li class="v1">V1</li></ul>   Pas d'information
# 824    <ul class="lignes"><li class="v1">V1</li></ul>      Mis en service
#
#     itineraire_prov_def              type_amenag niveau_valid_support_viaire  \
# 0             Définitif               Voie verte                    Variante
# 1             Définitif  Piste unidirectionnelle           Itinéraire validé
# 2             Définitif   Piste bidirectionnelle           Itinéraire validé
# 3             Définitif        Pas d'information           Itinéraire validé
# 4             Définitif  Piste unidirectionnelle           Itinéraire validé
# ..                  ...                      ...                         ...
# 820          Provisoire        Pas d'information           Itinéraire validé
# 821           Définitif                    Autre           Itinéraire validé
# 822           Définitif  Piste unidirectionnelle           Itinéraire validé
# 823           Définitif        Pas d'information           Itinéraire validé
# 824           Définitif   Piste bidirectionnelle           Itinéraire validé
#
#     iti_valid                                       geo_point_2d  \
# 0         Non  { "lon": 2.5304965462782931, "lat": 48.7513043...
# 1         Oui  { "lon": 2.4351528979658092, "lat": 48.8088099...
# 2         Oui  { "lon": 2.3517275175627685, "lat": 48.8510848...
# 3         Oui  { "lon": 2.3875359592495062, "lat": 48.6903866...
# 4         Oui  { "lon": 2.312486592604226, "lat": 48.78429879...
# ..        ...                                                ...
# 820       Oui  { "lon": 2.0971565019310825, "lat": 48.7406000...
# 821       Oui  { "lon": 2.315930080755499, "lat": 48.78085622...
# 822       Oui  { "lon": 2.3116172256047673, "lat": 48.7701762...
# 823       Oui  { "lon": 2.3054268762444909, "lat": 48.7544292...
# 824       Oui  { "lon": 2.3001353104092459, "lat": 48.7251585...
#
#                                               geometry route_velo     distance
# 0    MULTILINESTRING ((664838.031 6850465.318, 6649...         V6  1469.366215
# 1    MULTILINESTRING ((659395.727 6855973.898, 6592...         V6  2234.551472
# 2    MULTILINESTRING ((652070.079 6861643.593, 6521...         V7   837.213751
# 3    MULTILINESTRING ((655021.739 6843738.015, 6549...         V7   453.500265
# 4    MULTILINESTRING ((649677.626 6853889.101, 6495...        V20   459.786927
# ..                                                 ...        ...          ...
# 820  MULTILINESTRING ((633654.603 6849342.344, 6336...         V8   106.489326
# 821  MULTILINESTRING ((649685.269 6853466.763, 6497...         V1   352.383967
# 822  MULTILINESTRING ((649223.792 6851782.235, 6493...         V1  1388.413058
# 823  MULTILINESTRING ((648967.053 6850815.382, 6489...         V1   229.585736
# 824  MULTILINESTRING ((648564.705 6848031.916, 6485...         V1  1201.905357
#
# [951 rows x 11 columns]

# %%
route_velo = route_velo.to_crs("EPSG:2154")
route_velo['distance'] = route_velo.length

# %%
from bs4 import BeautifulSoup

def extract_tag(html):
    if not isinstance(html, str):
        return []
    soup = BeautifulSoup(html, 'html.parser')
    return [li.text.strip() for li in soup.find_all('li')]

route_velo['route_velo'] = route_velo['numero_ligne'].apply(extract_tag)
route_velo = route_velo.explode('route_velo')

# %%
route_velo.explore(column='route_velo',
                   cmap="tab10",
                   categorical=True,
                   legend=True,
                   tiles='CartoDB positron',
                   figsize=(8, 8))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8beb2dce39479e61d03cdedeba05098 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend route_velo&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;route_velo&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;V1&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff7f0e&#x27;&gt;&lt;/span&gt;V10&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#2ca02c&#x27;&gt;&lt;/span&gt;V2&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;V20&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9467bd&#x27;&gt;&lt;/span&gt;V3&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;V4&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e377c2&#x27;&gt;&lt;/span&gt;V5&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7f7f7f&#x27;&gt;&lt;/span&gt;V6&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#bcbd22&#x27;&gt;&lt;/span&gt;V7&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#17becf&#x27;&gt;&lt;/span&gt;V8&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#17becf&#x27;&gt;&lt;/span&gt;V9&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8beb2dce39479e61d03cdedeba05098&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8beb2dce39479e61d03cdedeba05098 = L.map(
#                 &quot;map_f8beb2dce39479e61d03cdedeba05098&quot;,
#                 {
#                     center: [48.78894669111058, 2.2521848683941466],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_f8beb2dce39479e61d03cdedeba05098);
#
#
#
#
#
#             var tile_layer_41361cbe6841f1d8c156ebbf201fcb4d = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_41361cbe6841f1d8c156ebbf201fcb4d.addTo(map_f8beb2dce39479e61d03cdedeba05098);
#
#
#             map_f8beb2dce3

# %%
import pandas as pd

# 1. Group by BOTH 'route' and 'status'
# This automatically creates a new line for every unique status a route has
velo = route_velo.groupby(['route_velo', 'niveau_valid_amenag'], as_index=False)['distance'].sum()

# 2. Rename columns to match your desired output
velo.columns = ['route', 'status', 'distance']

# 3. Sort Naturally (V2 before V10)
# We make a temporary helper column to turn "V10" into the number 10
velo['sort_helper'] = velo['route'].str.slice(1).astype(int)

# Sort by the helper number first, then by status
velo = velo.sort_values(by=['sort_helper', 'status'])

# Drop the helper column now that we are done
velo = velo.drop(columns='sort_helper')

velo
# Out:
#    route             status       distance
# 0     V1         En travaux    3714.037456
# 1     V1     Mis en service   41165.657527
# 2     V1  Pas d'information    5593.588461
# 3     V1          À l'étude    7044.005593
# 7     V2         En travaux     118.011912
# 8     V2     Mis en service   36657.436123
# 9     V2  Pas d'information    3697.416358
# 10    V2          À l'étude   10626.671813
# 15    V3         En travaux    3946.985699
# 16    V3     Mis en service   50036.582084
# 17    V3  Pas d'information    2595.893405
# 18    V3          À l'étude   23013.100665
# 19    V4         En travaux    5591.957092
# 20    V4     Mis en service   57091.231231
# 21    V4  Pas d'information    4563.766619
# 22    V4          À l'étude   24494.938556
# 23    V5         En travaux    3012.650024
# 24    V5     Mis en service   21393.782072
# 25    V5  Pas d'information   16583.424371
# 26    V5          À l'étude   14655.446078
# 27    V6         En travaux     446.777896
# 28    V6     Mis en service   35175.482038
# 29    V6  Pas d'information   27489.350617
# 30    V6          À l'étude   21689.030736
# 31    V7         En travaux    8610.240709
# 32    V7     Mis en service   40256.590639
# 33    V7  Pas d'information  103970.021283
# 34    V7          À l'étude   40659.167034
# 35    V8         En travaux    3320.068564
# 36    V8     Mis en service   37480.929432
# 37    V8  Pas d'information    5999.364801
# 38    V8          À l'étude   17886.987211
# 39    V9         En travaux    3157.188015
# 40    V9     Mis en service   25419.864695
# 41    V9  Pas d'information   25060.797387
# 42    V9          À l'étude   17946.967853
# 4    V10     Mis en service   30249.649334
# 5    V10  Pas d'information    3711.377596
# 6    V10          À l'étude    2866.628550
# 11   V20         En travaux    5306.856202
# 12   V20     Mis en service   28167.859830
# 13   V20  Pas d'information   14803.140091
# 14   V20          À l'étude   27454.936216

# %%
import plotly.express as px
fig = px.pie(velo , values='distance', names='status', title='VOie par type')

fig.show()
# Out:
# <div>                            <div id="7c98828a-0953-40de-87aa-5adcb179667f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c98828a-0953-40de-87aa-5adcb179667f")) {                    Plotly.newPlot(                        "7c98828a-0953-40de-87aa-5adcb179667f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"status=%{label}\u003cbr\u003edistance=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["En travaux","Mis en service","Pas d'information","\u00c0 l'\u00e9tude","En travaux","Mis en service","Pas d'information","\u00c0 l'\u00e9tude","En travaux","Mis en service","Pas d'information","\u00c0 l'\u00e9tude","En travaux","Mis en service","Pas d'information","\u00c0 l'\u00e9tude","En travaux","Mis en service","Pas d'information","\u00c0 l'\u00e9tude","En travaux","Mis en service","Pas d'information","\u00c0 l'\u00e9tude","En travaux","Mis en service","Pas d'information","\u00c0 l'\u00e9tude","En travaux","Mis en service","Pas d'information","\u00c0 l'\u00e9tude","En travaux","Mis en service","Pas d'information","\u00c0 l'\u00e9tude","Mis en service","Pas d'information","\u00c0 l'\u00e9tude","En travaux","Mis en service","Pas d'information","\u00c0 l'\u00e9tude"],"legendgroup":"","name":"","showlegend":true,"values":[3714.03745639741,41165.65752704401,5593.588460965587,7044.005592949277,118.01191162617118,36657.43612285988,3697.4163578030107,10626.671812586328,3946.985698928111,50036.58208378738,2595.8934045479004,23013.100665179023,5591.957092029188,57091.23123140537,4563.766619384171,24494.93855595369,3012.650023732305,21393.78207175051,16583.42437071128,14655.44607815261,446.7778963841733,35175.482037633854,27489.350617017382,21689.030736384193,8610.240709186335,40256.590639072136,103970.02128315595,40659.16703443925,3320.068563959452,37480.92943218983,5999.364801123334,17886.987211150365,3157.188015330362,25419.864694607015,25060.797386934613,17946.967852970774,30249.649333739166,3711.377596320983,2866.628550128169,5306.856202109266,28167.859829882032,14803.140091062818,27454.936216219456],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","color ...

# %%
fig = px.bar(velo, x='route', y='distance', color='status', title='Status travaux')
fig.show()
# Out:
# <div>                            <div id="31bada93-d6e1-401d-b6ce-27c73b177947" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31bada93-d6e1-401d-b6ce-27c73b177947")) {                    Plotly.newPlot(                        "31bada93-d6e1-401d-b6ce-27c73b177947",                        [{"alignmentgroup":"True","hovertemplate":"status=En travaux\u003cbr\u003eroute=%{x}\u003cbr\u003edistance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"En travaux","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"En travaux","offsetgroup":"En travaux","orientation":"v","showlegend":true,"textposition":"auto","x":["V1","V2","V3","V4","V5","V6","V7","V8","V9","V20"],"xaxis":"x","y":[3714.03745639741,118.01191162617118,3946.985698928111,5591.957092029188,3012.650023732305,446.7778963841733,8610.240709186335,3320.068563959452,3157.188015330362,5306.856202109266],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status=Mis en service\u003cbr\u003eroute=%{x}\u003cbr\u003edistance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mis en service","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Mis en service","offsetgroup":"Mis en service","orientation":"v","showlegend":true,"textposition":"auto","x":["V1","V2","V3","V4","V5","V6","V7","V8","V9","V10","V20"],"xaxis":"x","y":[41165.65752704401,36657.43612285988,50036.58208378738,57091.23123140537,21393.78207175051,35175.482037633854,40256.590639072136,37480.92943218983,25419.864694607015,30249.649333739166,28167.859829882032],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status=Pas d'information\u003cbr\u003eroute=%{x}\u003cbr\u003edistance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pas d'information","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Pas d'information","offsetgroup":"Pas d'information","orientation":"v","showlegend":true,"textposition":"auto","x":["V1","V2","V3","V4","V5","V6","V7","V8","V9","V10","V20"],"xaxis":"x","y":[5593.588460965587,3697.4163578030107,2595.8934045479004,4563.766619384171,16583.42437071128,27489.350617017382,103970.02128315595,5999.364801123334,25060.797386934613,3711.377596320983,14803.140091062818],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status=\u00c0 l'\u00e9tude\u003cbr\u003eroute=%{x}\u003cbr\u003edistance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u00c0 l'\u00e9tude","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u00c0 l'\u00e9tude","offsetgroup":"\u00c0 l'\u00e9tude","orientation":"v","showlegend":true,"textposition":"auto","x":["V1","V2","V3","V4","V5","V6","V7","V8","V9","V10","V20"],"xaxis":"x","y":[7044.005592949277,10626.671812586328,23013.100665179023,24494.93855595369,14655.44607815261,21689.030736384193,40659.16703443925,17886.987211150365,17946.967852970774,2866.628550128169,27454.936216219456],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9 ...

# %%
point = [48.912196, 2.373194]
from shapely.geometry import Point

centroid = geopandas.GeoSeries(
    Point(point[1], point[0]),
    crs="EPSG:4326"
)

centroid = centroid.to_crs("EPSG:2154")
buffer = centroid.buffer(5000)

route_velo_Saint_Denis = route_velo.to_crs("EPSG:2154")
route_velo_Saint_Denis = route_velo_Saint_Denis[route_velo_Saint_Denis.intersects(buffer.iloc[0])]

route_velo_Saint_Denis = route_velo_Saint_Denis.to_crs(epsg=4326)
buffer = buffer.to_crs(epsg=4326)

# %%
import geopandas as gpd

buffer = buffer.to_frame(name="geometry")
buffer = buffer.set_geometry("geometry")
buffer["label"] = "20 min de vélo"


buffer
# Out:
#                                             geometry           label
# 0  POLYGON ((2.44141 48.91253, 2.44113 48.90812, ...  20 min de vélo

# %%
m = route_velo_Saint_Denis .explore(
    column="route_velo",
    categorical=True,
    cmap="tab10",
    legend=True ,
    location=point,
    tiles='Stadia.OSMBright',
    zoom_start=14
)



m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c068be4c44703a6e15e8ed48b5088e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend route_velo&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;route_velo&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;V1&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff7f0e&#x27;&gt;&lt;/span&gt;V10&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;V2&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;V20&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e377c2&#x27;&gt;&lt;/span&gt;V3&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#bcbd22&#x27;&gt;&lt;/span&gt;V6&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#17becf&#x27;&gt;&lt;/span&gt;V7&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c068be4c44703a6e15e8ed48b5088e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c068be4c44703a6e15e8ed48b5088e3 = L.map(
#                 &quot;map_3c068be4c44703a6e15e8ed48b5088e3&quot;,
#                 {
#                     center: [48.912196, 2.373194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3c068be4c44703a6e15e8ed48b5088e3);
#
#
#
#
#
#             var tile_layer_08aae9e9a68d835fe4eab7090f0d30c1 = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://stadiamaps.com/\&quot;\u003eStadia Maps\u003c/a\u003e, \u0026copy; \u003ca href=\&quot;https://openmaptiles.org/\&quot;\u003eOpenMapTiles\u003c/a\u003e \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08aae9e9a68d835fe4eab7090f0d30c1.addTo(map_3c068be4c44703a6e15e8ed48b5088e3);
#
#
#         function geo_json_a198944fe6a9d9439145a217ee1355c9_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;5&quot;: case &quot;17&quot;: case &quot;32&quot;: case &quot;59&quot;: case &quot;61&quot;: case &quot;64&quot;: case &quot;67&quot;: case &quot;85&quot;: case &quot;88&quot;: case &quot;98&quot;: case &quot;

# %% [markdown]
# Section 3 : Type d'aménagement

# %%
piste_cyclable = geopandas.read_file('amenagements-velo-en-ile-de-france.geojson')

# %%
zone_interest = piste_cyclable[piste_cyclable['nom_com'].isin([ 'Aubervilliers', 'Saint-Denis'])]
zone_interest
# Out:
#        geo_shape        osm_id        highway sens_voit   revetement panneaux  \
# 3611        None  3.019098e+08  living_street    UNIQUE      asphalt     None
# 3612        None  3.810717e+08  living_street    UNIQUE      asphalt     None
# 3613        None  6.907535e+08    residential    DOUBLE      asphalt     None
# 3614        None  1.429229e+09    residential    DOUBLE      asphalt     None
# 3615        None  1.336951e+09       cycleway    UNIQUE      asphalt     None
# ...          ...           ...            ...       ...          ...      ...
# 142325      None  1.091046e+08    residential    UNIQUE      asphalt     None
# 142326      None  8.685641e+08        footway        NC      asphalt     None
# 142327      None  3.666945e+08    residential    DOUBLE      asphalt     None
# 142333      None  3.319021e+08           path        NC  fine_gravel     None
# 142334      None  3.383249e+08       cycleway    UNIQUE      asphalt     None
#
#                         ad              ag           nv moyenn_ech petite_ech  \
# 3611                  None             DSC          z20         33          3
# 3612                  None            None          z20         33          3
# 3613             bande uni       bande uni         None         21          2
# 3614             bande uni       bande uni         None         21          2
# 3615             piste uni            None  hors voirie         12          1
# ...                    ...             ...          ...        ...        ...
# 142325                None             DSC    limite 30         32          3
# 142326  piste trottoir uni            None  hors voirie         12          1
# 142327                None            None    limite 30         32          3
# 142333      voie verte uni  voie verte uni  hors voirie         11          1
# 142334           piste uni            None  hors voirie         12          1
#
#        insee_com        nom_com               nom_voie  longueur notes  \
# 3611       93066    Saint-Denis           Rue Chaudron       196  None
# 3612       93066    Saint-Denis             Rue Legras        89  None
# 3613       93001  Aubervilliers          Rue Léon Blum        57  None
# 3614       93066    Saint-Denis           Rue Proudhon         2  None
# 3615       93001  Aubervilliers  Rue Madeleine Vionnet        97  None
# ...          ...            ...                    ...       ...   ...
# 142325     93066    Saint-Denis            Rue Roussel       159  None
# 142326     93066    Saint-Denis                   None       261  None
# 142327     93066    Saint-Denis        Rue Paul Éluard        91  None
# 142333     93066    Saint-Denis                   None        44  None
# 142334     93066    Saint-Denis                   None        40  None
#
#                                              geo_point_2d  \
# 3611    { "lon": 2.3611415429170823, "lat": 48.9073778...
# 3612    { "lon": 2.3624547474274125, "lat": 48.9068851...
# 3613    { "lon": 2.3669385024116596, "lat": 48.9070514...
# 3614    { "lon": 2.3659893499999942, "lat": 48.9063817...
# 3615    { "lon": 2.3766194678358055, "lat": 48.9066063...
# ...                                                   ...
# 142325  { "lon": 2.3510338461294262, "lat": 48.9397354...
# 142326  { "lon": 2.349064304074711, "lat": 48.93879706...
# 142327  { "lon": 2.3465942683439458, "lat": 48.9392389...
# 142333  { "lon": 2.3411803959497948, "lat": 48.9410507...
# 142334  { "lon": 2.3461861497023149, "lat": 48.9462969...
#
#                                                  geometry
# 3611    LINESTRING (2.35981 48.90749, 2.35991 48.90747...
# 3612    LINESTRING (2.36247 48.90729, 2.36247 48.90725...
# 3613    LINESTRING (2.36691 48.9068, 2.36692 48.90692,...
# 3614        LINESTRING (2.36598 48.90638, 2.366 48.90638)
# 3615    LINESTRING (2.37677 48.90619, 2.37679 48.90636...
# ...                                                   ...
# 142325  LINESTRING (2.35073 48.93926, 2.35081 48.93926...
# 142326  LINESTRING (2.34734 48.93909, 2.34756 48.93906...
# 142327  LINESTRING (2.34599 48.93933, 2.34617 48.9393,...
# 142333  LINESTRING (2.34114 48.94085, 2.34121 48.94121...
# 142334    LINESTRING (2.34592 48.94635, 2.34645 48.94624)
#
# [1484 rows x 18 columns]

# %%
mask = (
    (zone_interest['ad'] != zone_interest['ag']) &
    (zone_interest['ad'].notna()) &
    (zone_interest['ag'].notna())
)
zone_interest.loc[mask, 'longueur'] = zone_interest.loc[mask, 'longueur'] / 2
zone_interest[
    (zone_interest['ad'] != zone_interest['ag']) &
    (zone_interest['ad'].notna()) &
    (zone_interest['ag'].notna())]
# Out:
# /tmp/ipykernel_50549/3136350160.py:6: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 24.5  42.5  16.5  42.   13.5  67.5 103.   11.5  21.5  40.5  59.5   6.
#   18.   68.   14.5  27.   58.5 132.  142.5   4.5  35.   66.5 124.   70.
#    5.   92.5  28.   92.5   0.    7.   42.5]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#        geo_shape        osm_id        highway sens_voit revetement panneaux  \
# 5786        None  4.632588e+08    residential    UNIQUE    asphalt     None
# 6317        None  1.129100e+07    residential    UNIQUE    asphalt     None
# 15175       None  6.366149e+08      secondary    DOUBLE    asphalt     None
# 15244       None  1.129105e+07    residential    UNIQUE       sett     None
# 22897       None  1.063576e+08    residential    UNIQUE    asphalt     None
# 22993       None  1.011752e+09    residential    UNIQUE    asphalt     None
# 35956       None  1.083109e+08    residential    DOUBLE    asphalt     None
# 35996       None  1.391808e+09    residential    UNIQUE    asphalt     None
# 36002       None  6.733521e+08        primary    UNIQUE    asphalt     None
# 36044       None  1.005019e+09    residential    UNIQUE       sett     None
# 50661       None  1.090991e+08  living_street    UNIQUE       sett     None
# 60299       None  1.227366e+09    residential    DOUBLE    asphalt     None
# 62069       None  6.366149e+08      secondary    DOUBLE    asphalt     None
# 62075       None  2.459494e+07    residential    DOUBLE    asphalt     None
# 62125       None  6.733521e+08        primary    UNIQUE    asphalt     None
# 72116       None  6.733521e+08        primary    UNIQUE    asphalt     None
# 88544       None  6.927429e+08        primary    DOUBLE    asphalt  FR:C113
# 89121       None  3.309429e+08    residential    DOUBLE    asphalt     None
# 93325       None  6.366149e+08      secondary    DOUBLE    asphalt     None
# 93335       None  1.333499e+09    residential    UNIQUE    asphalt     None
# 94506       None  5.840342e+08    residential    UNIQUE    asphalt     None
# 112256      None  8.193242e+07    residential    UNIQUE    asphalt     None
# 112268      None  3.309429e+08    residential    DOUBLE    asphalt     None
# 116653      None  4.632588e+08    residential    UNIQUE    asphalt     None
# 117309      None  1.209845e+09    residential    UNIQUE       sett     None
# 130264      None  2.478993e+08    residential    DOUBLE    asphalt     None
# 137267      None  5.433337e+08    residential    UNIQUE    asphalt     None
# 137809      None  4.868771e+07   unclassified    DOUBLE    asphalt     None
# 142253      None  6.366149e+08      secondary    DOUBLE    asphalt     None
# 142278      None  6.733521e+08        primary    UNIQUE    asphalt     None
# 142319      None  2.888431e+07    residential    UNIQUE       sett     None
#
#                      ad               ag         nv moyenn_ech petite_ech  \
# 5786    cheminement uni        DSC bande       None         22          2
# 6317    cheminement uni        DSC bande  limite 30         22          2
# 15175         piste uni  cheminement uni       None         12          1
# 15244   cheminement uni        DSC bande  limite 30         22          2
# 22897         piste uni              DSC       None         12          1
# 22993   cheminement uni              DSC       None         34          3
# 35956         bande uni        piste uni       None         12          1
# 35996   cheminement uni        DSC bande       None         22          2
# 36002   cheminement uni        bande uni       None         22          2
# 36044   cheminement uni        DSC bande  limite 30         22          2
# 50661         piste uni              DSC        z20         12          1
# 60299         bande uni        piste uni       None         12          1
# 62069         piste uni  cheminement uni       None         12          1
# 62075         piste uni        bande uni       None         12          1
# 62125   cheminement uni        bande uni       None         22          2
# 72116   cheminement uni        bande uni       None         22          2
# 88544         bande uni  cheminement uni  limite 30         22          2
# 89121         piste uni        bande uni  limite 30         12          1
# 93325         piste uni  cheminement uni       None         12          1
# 93335         bande uni        DSC bande       None         21          2
# 94506   cheminement uni        DSC bande  limite 30         22          2
# 112256  cheminement uni              DSC       None         34          3
# 112268        bande uni        piste uni       None         12          1
# 116653  cheminement uni        DSC bande       None         22          2
# 117309  cheminement uni        DSC bande  limite 30         22          2
# 130264        piste uni        bande uni       None         12          1
# 137267        piste uni              DSC       None         12          1
# 137809        piste uni        bande uni  limite 30         12          1
# 142253        piste uni  cheminement uni       None         12          1
# 142278  cheminement uni        bande uni       None         22          2
# 142319  cheminement uni        DSC bande  limite 30         22          2
#
#        insee_com        nom_com                        nom_voie  longueur  \
# 5786       93066    Saint-Denis                Rue Camille Moke      24.5
# 6317       93066    Saint-Denis                 Rue Paul Éluard      42.5
# 15175      93066    Saint-Denis                    Rue du Landy      16.5
# 15244      93066    Saint-Denis                     Rue Gisquet      42.0
# 22897      93066    Saint-Denis                    Rue Guynemer      13.5
# 22993      93066    Saint-Denis         Avenue Henri Rol-Tanguy      67.5
# 35956      93066    Saint-Denis            Avenue des Fruitiers     103.0
# 35996      93066    Saint-Denis                Rue Camille Moke      11.5
# 36002      93066    Saint-Denis      Boulevard de la Libération      21.5
# 36044      93066    Saint-Denis                     Rue Dézobry      40.5
# 50661      93066    Saint-Denis      Rue de la Légion d'Honneur      59.5
# 60299      93066    Saint-Denis           Avenue Amilcar Cabral       6.0
# 62069      93066    Saint-Denis                    Rue du Landy      18.0
# 62075      93066    Saint-Denis                Rue Camille Moke      68.0
# 62125      93066    Saint-Denis      Boulevard de la Libération      14.5
# 72116      93066    Saint-Denis      Boulevard de la Libération      27.0
# 88544      93066    Saint-Denis  Avenue Paul Vaillant-Couturier      58.5
# 89121      93066    Saint-Denis              Avenue George Sand     132.0
# 93325      93066    Saint-Denis                    Rue du Landy     142.5
# 93335      93066    Saint-Denis                Rue Camille Moke       4.5
# 94506      93066    Saint-Denis                 Rue Paul Éluard      35.0
# 112256     93066    Saint-Denis             Rue Mumia Abu-Jamal      66.5
# 112268     93066    Saint-Denis           Avenue Amilcar Cabral     124.0
# 116653     93066    Saint-Denis                Rue Camille Moke      70.0
# 117309     93066    Saint-Denis                       Rue Suger       5.0
# 130264     93066    Saint-Denis        Rue Jean-Philippe Rameau      92.5
# 137267     93066    Saint-Denis                    Rue Guynemer      28.0
# 137809     93001  Aubervilliers              Rue Waldeck Rochet      92.5
# 142253     93066    Saint-Denis                    Rue du Landy       0.0
# 142278     93066    Saint-Denis      Boulevard de la Libération       7.0
# 142319     93066    Saint-Denis                       Rue Suger      42.5
#
#        notes                                       geo_point_2d  \
# 5786    None  { "lon": 2.3494689999999947, "lat": 48.9227438...
# 6317    None  { "lon": 2.3454291027211287, "lat": 48.9393743...
# 15175   None  { "lon": 2.3384066569236328, "lat": 48.9149585...
# 15244   None  { "lon": 2.3464426036438195, "lat": 48.9385717...
# 22897   None    { "lon": 2.3633202, "lat": 48.946008050000003 }
# 22993   None  { "lon": 2.3644129144280321, "lat": 48.9178174...
# 35956   None  { "lon": 2.3548183018622724, "lat": 48.9162637...
# 35996   None   { "lon": 2.34959015, "lat": 48.922430399999996 }
# 36002   None  { "lon": 2.3418246315312925, "lat": 48.9264954...
# 36044   None  { "lon": 2.348288686807253, "lat": 48.93858662...
# 50661   None  { "lon": 2.3577455595974124, "lat": 48.9334579...
# 60299   None  { "lon": 2.3630396346125049, "lat": 48.9136299...
# 62069   None  { "lon": 2.3380078073909467, "lat": 48.9151206...
# 62075   None  { "lon": 2.3515325223333234, "lat": 48.9213812...
# 62125   None  { "lon": 2.3417277579456006, "lat": 48.9268092...
# 72116   None  { "lon": 2.3416260118225107, "lat": 48.9271755...
# 88544   None  { "lon": 2.3628569760616123, "lat": 48.9306047...
# 89121   None  { "lon": 2.3653167285875938, "lat": 48.9142259...
# 93325   None  { "lon": 2.3404630453297322, "lat": 48.9145107...
# 93335   None  { "lon": 2.3512866877282179, "lat": 48.9220767...
# 94506   None  { "lon": 2.3455235536666947, "lat": 48.9393991...
# 112256  None  { "lon": 2.3633599009449755, "lat": 48.9171628...
# 112268  None  { "lon": 2.3646953682309682, "lat": 48.9132775...
# 116653  None  { "lon": 2.3491476300612182, "lat": 48.9235587...
# 117309  None  { "lon": 2.3501218500000061, "lat": 48.9372782...
# 130264  None  { "lon": 2.3529307986273142, "lat": 48.9208443...
# 137267  None  { "lon": 2.3636182975704925, "lat": 48.9456897...
# 137809  None  { "lon": 2.3677213338667751, "lat": 48.9118839...
# 142253  None  { "lon": 2.3378062000530404, "lat": 48.9152140...
# 142278  None  { "lon": 2.341548850000005, "lat": 48.92747859...
# 142319  None  { "lon": 2.3494946461050819, "lat": 48.9373684...
#
#                                                  geometry
# 5786      LINESTRING (2.34956 48.92253, 2.34938 48.92296)
# 6317    LINESTRING (2.3449 48.93949, 2.34494 48.93944,...
# 15175   LINESTRING (2.3386 48.91488, 2.33851 48.91492,...
# 15244   LINESTRING (2.347 48.93849, 2.34598 48.93864, ...
# 22897      LINESTRING (2.36322 48.94611, 2.36342 48.9459)
# 22993   LINESTRING (2.3635 48.91783, 2.36359 48.91783,...
# 35956   LINESTRING (2.35471 48.91719, 2.35472 48.91714...
# 35996     LINESTRING (2.34962 48.92233, 2.34956 48.92253)
# 36002   LINESTRING (2.34188 48.92631, 2.34186 48.92638...
# 36044   LINESTRING (2.34819 48.93823, 2.34821 48.93832...
# 50661   LINESTRING (2.35753 48.93294, 2.35756 48.93303...
# 60299   LINESTRING (2.36296 48.91364, 2.36307 48.91363...
# 62069   LINESTRING (2.33821 48.91503, 2.33821 48.91503...
# 62075   LINESTRING (2.35167 48.92078, 2.35165 48.92084...
# 62125   LINESTRING (2.34177 48.92668, 2.34174 48.92677...
# 72116   LINESTRING (2.34169 48.92694, 2.34164 48.92709...
# 88544   LINESTRING (2.3623 48.93023, 2.36292 48.93065,...
# 89121   LINESTRING (2.36549 48.91305, 2.3655 48.91313,...
# 93325   LINESTRING (2.34235 48.91427, 2.34235 48.91427...
# 93335   LINESTRING (2.35135 48.92207, 2.3513 48.92208,...
# 94506   LINESTRING (2.34599 48.93933, 2.34527 48.93944...
# 112256  LINESTRING (2.36336 48.91656, 2.36336 48.91661...
# 112268  LINESTRING (2.36312 48.91362, 2.36391 48.91355...
# 116653  LINESTRING (2.34938 48.92296, 2.34934 48.92303...
# 117309    LINESTRING (2.35006 48.93729, 2.35019 48.93727)
# 130264  LINESTRING (2.35419 48.92091, 2.35405 48.9209,...
# 137267  LINESTRING (2.36342 48.9459, 2.3636 48.94571, ...
# 137809  LINESTRING (2.36757 48.91106, 2.36758 48.91109...
# 142253    LINESTRING (2.33781 48.91521, 2.33781 48.91521)
# 142278    LINESTRING (2.34157 48.92742, 2.34153 48.92754)
# 142319  LINESTRING (2.34894 48.93747, 2.34907 48.93743...

# %%
def combine_cols (row, col1, col2) :
    value1,value2 = row[col1], row[col2]
    if pd.isnull(value1) & pd.isnull(value2) :
        return None
    elif pd.isnull(value1) :
        return value2
    elif pd.isnull(value2) :
        return value1
    elif value1 == value2 :
        return value1
    else :
        return [value1,value2]

zone_interest['type voie'] = zone_interest.apply(combine_cols,args=('ad','ag'), axis=1)
zone_interest = zone_interest.explode('type voie')
# Out:
# /home/lecaotunglam/anaconda3/lib/python3.13/site-packages/geopandas/geodataframe.py:1968: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
replacement_map = {
    'bande bi': "voie partage avec d'autre véhicule sans protection et priorité",
    'bande uni': "voie partage avec d'autre véhicule sans protection et priorité",
    'DSC': "voie partage avec d'autre véhicule sans protection et priorité",
    'DSC bande': "voie partage avec d'autre véhicule sans protection et priorité",
    'DSC piste': "voie partage avec protection et priorité",
    'piste bi': "voie partage avec protection et priorité",
    'piste uni': "voie partage avec protection et priorité",
    'voie bus bi': "voie partage avec protection et priorité",
    'voie bus uni': "voie partage avec protection et priorité",
    'voie verte uni': "voie partage piéton",
    'piste trottoir uni': "voie partage piéton",
    'cheminement trottoir uni': "voie partage piéton",
    'chemin service site propre uni': "voie partage piéton",
    'chemin dedie uni': "voie partage piéton",
    'autre chemin velo uni': "voie partage piéton",
    'cheminement uni': "voie partage piéton",
    'goulotte': "autre"
}

# Apply the replacement
zone_interest['type voie'] = zone_interest['type voie'].replace(replacement_map)
zone_interest['type voie'] = zone_interest['type voie'].fillna('voie sans aménagement')

# %%
point = [48.912196, 2.373194]
from shapely.geometry import Point

centroid = geopandas.GeoSeries(
    Point(point[1], point[0]),
    crs="EPSG:4326"
)

centroid = centroid.to_crs("EPSG:2154")
buffer = centroid.buffer(2000)

zone_velo_Saint_Denis = zone_interest.to_crs("EPSG:2154")
zone_velo_Saint_Denis = zone_velo_Saint_Denis[zone_velo_Saint_Denis.intersects(buffer.iloc[0])]

zone_velo_Saint_Denis = zone_velo_Saint_Denis.to_crs(epsg=4326)
buffer = buffer.to_crs(epsg=4326)

# %%
import xyzservices.providers as xyz
zone_velo_Saint_Denis.explore(tiles='Stadia.OSMBright',
                       column="type voie",
    categorical=True,
    cmap="tab10",
    legend=True ,
                              location=point,
                              zoom_start=15,


                   figsize=(8, 8))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80f35c8730192e39403e641285c7be28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend type voie&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;type voie&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;autre&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#2ca02c&#x27;&gt;&lt;/span&gt;voie partage avec d&#x27;autre véhicule sans protection et priorité&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;voie partage avec protection et priorité&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7f7f7f&#x27;&gt;&lt;/span&gt;voie partage piéton&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#17becf&#x27;&gt;&lt;/span&gt;voie sans aménagement&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80f35c8730192e39403e641285c7be28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80f35c8730192e39403e641285c7be28 = L.map(
#                 &quot;map_80f35c8730192e39403e641285c7be28&quot;,
#                 {
#                     center: [48.912196, 2.373194],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_80f35c8730192e39403e641285c7be28);
#
#
#
#
#
#             var tile_layer_f9d57870321da4204f801b1994324d5e = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://stadiamaps.com/\&quot;\u003eStadia Maps\u003c/a\u003e, \u0026copy; \u003ca href=\&quot;https://openmaptiles.org/\&quot;\u003eOpenMapTiles\u003c/a\u003e \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9d57870321da4204f801b1994324d5e.addTo(map_80f35c8730192e39403e641285c7be28);
#
#
#         function geo_json_e3ea444e2bd8367c80cf42228feac4eb_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;11&quot;: case &quot;20&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;37&quot;: case &quot;47&quot;: case &quot;48&q

# %%
import plotly.express as px
fig = px.pie(zone_velo_Saint_Denis , values='longueur', names='type voie', title='VOie par type')
fig.show()
# Out:
# <div>                            <div id="3e47e77a-e523-42af-a1c2-4d32e7e47ffa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e47e77a-e523-42af-a1c2-4d32e7e47ffa")) {                    Plotly.newPlot(                        "3e47e77a-e523-42af-a1c2-4d32e7e47ffa",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"type voie=%{label}\u003cbr\u003elongueur=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie sans am\u00e9nagement","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie partage pi\u00e9ton","voie sans am\u00e9nagement","voie partage pi\u00e9ton","voie partage pi\u00e9ton","voie partage avec protection et priorit\u00e9","voie sans am\u00e9nagement","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage pi\u00e9ton","voie sans am\u00e9nagement","voie partage avec protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie sans am\u00e9nagement","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie sans am\u00e9nagement","voie partage avec protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage pi\u00e9ton","voie partage pi\u00e9ton","voie partage pi\u00e9ton","voie sans am\u00e9nagement","voie partage pi\u00e9ton","voie partage avec protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie partage pi\u00e9ton","voie partage pi\u00e9ton","voie sans am\u00e9nagement","voie sans am\u00e9nagement","voie partage pi\u00e9ton","voie partage pi\u00e9ton","voie partage pi\u00e9ton","voie partage avec protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie sans am\u00e9nagement","voie partage avec protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie sans am\u00e9nagement","voie partage pi\u00e9ton","voie partage avec protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage pi\u00e9ton","voie partage pi\u00e9ton","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage pi\u00e9ton","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie partage avec d'autre v\u00e9hicule sans protection et priorit\u00e9","voie partage pi\u00e9ton","voie sans am\u00e9nagement","autre","voie partage avec protection et priorit\u00e9","voie partage avec protection et priorit\u00e9","voie partage avec protection et pri ...
